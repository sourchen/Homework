# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
 
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, f(X, Y))

plt.show()
